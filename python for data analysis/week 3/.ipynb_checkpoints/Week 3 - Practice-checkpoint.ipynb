# %%
import pandas as pd

# First we create two DataFrames, staff and students.
staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR'},
                         {'Name': 'Sally', 'Role': 'Course liasion'},
                         {'Name': 'James', 'Role': 'Grader'}])

# Now we'll create a student dataframe
student_df = pd.DataFrame([{'Name': 'James', 'School': 'Business'},
                           {'Name': 'Mike', 'School': 'Law'},
                           {'Name': 'Sally', 'School': 'Engineering'}])

# set indexes
staff_df = staff_df.set_index("Name")
student_df = student_df.set_index("Name")

# %%
# do an inner join (union) of both dfs using merge
pd.merge(staff_df, student_df, how="outer", left_index = True, right_index = True)

# %%
# %%capture
df_2010 = pd.read_csv("datasets/MERGED2010_11_PP.csv", error_bad_lines=False)
df_2012 = pd.read_csv("datasets/MERGED2012_13_PP.csv", error_bad_lines=False)
df_2013 = pd.read_csv("datasets/MERGED2013_14_PP.csv", error_bad_lines=False)

# %%
df_2010.head(3)

# %%
all = [df_2010, df_2012, df_2013]

# %%
pd.concat(all, keys=['2010', '2012', '2013'])

# %%
len(df_2010)+len(df_2012)+len(df_2013)

# %% [markdown]
# # Pandas Idioms

# %%
import pandas as pd
import numpy as np

import timeit

# %%
df = pd.read_csv('datasets/census.csv')
df.head(10)

# %%
(df.where((df['SUMLEV']==50)&(df['REGION']==3.0))
    .dropna()
    .set_index(['STNAME', 'CTYNAME'])
    .rename(columns={'ESTIMATEBASE2010': 'Esimates Base 2010'}))
# Out:
#                               SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME        CTYNAME
# Alabama       Autauga County    50.0     3.0       6.0    1.0     1.0
#               Baldwin County    50.0     3.0       6.0    1.0     3.0
#               Barbour County    50.0     3.0       6.0    1.0     5.0
#               Bibb County       50.0     3.0       6.0    1.0     7.0
#               Blount County     50.0     3.0       6.0    1.0     9.0
# ...                              ...     ...       ...    ...     ...
# West Virginia Webster County    50.0     3.0       5.0   54.0   101.0
#               Wetzel County     50.0     3.0       5.0   54.0   103.0
#               Wirt County       50.0     3.0       5.0   54.0   105.0
#               Wood County       50.0     3.0       5.0   54.0   107.0
#               Wyoming County    50.0     3.0       5.0   54.0   109.0
#
#                               CENSUS2010POP  ESTIMATESBASE2010  \
# STNAME        CTYNAME
# ...

# %%
def min_max(row):
    data = row[['POPESTIMATE2010',
            'POPESTIMATE2011',
            'POPESTIMATE2012',
            'POPESTIMATE2013',
            'POPESTIMATE2014',
            'POPESTIMATE2015']]
    
    row['max'] = np.max(data)
    
    return(row)
    
    
df.apply(min_max, axis=1)
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
def get_state_region(x):
    northeast = ['Connecticut', 'Maine', 'Massachusetts', 'New Hampshire', 
                 'Rhode Island','Vermont','New York','New Jersey','Pennsylvania']
    midwest = ['Illinois','Indiana','Michigan','Ohio','Wisconsin','Iowa',
               'Kansas','Minnesota','Missouri','Nebraska','North Dakota',
               'South Dakota']
    south = ['Delaware','Florida','Georgia','Maryland','North Carolina',
             'South Carolina','Virginia','District of Columbia','West Virginia',
             'Alabama','Kentucky','Mississippi','Tennessee','Arkansas',
             'Louisiana','Oklahoma','Texas']
    west = ['Arizona','Colorado','Idaho','Montana','Nevada','New Mexico','Utah',
            'Wyoming','Alaska','California','Hawaii','Oregon','Washington']
    
    if x in northeast:
        return "Northeast"
    elif x in midwest:
        return "Midwest"
    elif x in south:
        return "South"
    else:
        return "West"

# %%
df['state_region'] = df['STNAME'].apply(lambda x: get_state_region(x))

# %%
# Now let's see the results
df[['STNAME','state_region']].head()
# Out:
#     STNAME state_region
# 0  Alabama        South
# 1  Alabama        South
# 2  Alabama        South
# 3  Alabama        South
# 4  Alabama        South

# %%
df.columns
# Out:
# Index(['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'COUNTY', 'STNAME', 'CTYNAME',
#        'CENSUS2010POP', 'ESTIMATESBASE2010', 'POPESTIMATE2010',
#        ...
#        'RDOMESTICMIG2012', 'RDOMESTICMIG2013', 'RDOMESTICMIG2014',
#        'RDOMESTICMIG2015', 'RNETMIG2011', 'RNETMIG2012', 'RNETMIG2013',
#        'RNETMIG2014', 'RNETMIG2015', 'state_region'],
#       dtype='object', length=101)

# %%
df = df.rename(columns = str.upper)

# %%
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...
